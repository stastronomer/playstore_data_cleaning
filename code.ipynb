# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('googleplaystore.csv')
df.sample(5)
# Out:
#                                                   App      Category  Rating
# 8654  TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6  \
# 4117                   Inputting Plus: Ctrl + Z/F/C/V  PRODUCTIVITY     4.2
# 9845                               Empires and Allies        FAMILY     4.3
# 6846                                  Bu Hangi Dizi ?          GAME     NaN
# 6078                                        YAY - TBH        SOCIAL     4.1
#
#      Reviews                Size     Installs  Type Price Content Rating
# 8654   25370  Varies with device   1,000,000+  Free     0       Everyone  \
# 4117    1117                3.0M      50,000+  Free     0       Everyone
# 9845  398746  Varies with device  10,000,000+  Free     0   Everyone 10+
# 6846      14                 19M       1,000+  Free     0       Everyone
# 6078    2520                 12M     100,000+  Free     0           Teen
#
#             Genres       Last Updated         Current Ver         Android Ver
# 8654  Productivity     August 6, 2018  Varies with device  Varies with device
# 4117  Productivity   October 18, 2017               1.0.6          5.0 and up
# 9845      Strategy     August 6, 2018  Varies with device          4.1 and up
# 6846        Trivia        May 4, 2018              3.1.7z        4.0.3 and up
# 6078        Social  November 17, 2017               1.1.5          4.3 and up

# %% [markdown]
# ##### 1. Which of the following column(s) has/have null values?

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Rating            1474
# Current Ver          8
# Android Ver          3
# Type                 1
# Content Rating       1
# App                  0
# Category             0
# Reviews              0
# Size                 0
# Installs             0
# Price                0
# Genres               0
# Last Updated         0
# dtype: int64

# %% [markdown]
# ##### 2. Clean the `Rating` column and the other columns containing null values

# %%
df.loc[df['Rating'] > 5, 'Rating'] = np.nan
df['Rating'] = df['Rating'].fillna(df['Rating'].mean())
df.dropna(inplace=True)

# %% [markdown]
# ##### 3. Clean the column `Reviews` and make it numeric

# %%
#Clean the column Reviews and make it numeric
df.loc[df['Reviews'].str.contains('M'), 'Reviews'] = (pd.to_numeric(
    df.loc[df['Reviews'].str.contains('M'), 'Reviews'].str.replace('M', '')) * 1_000_000).astype('str')
df['Reviews'] = pd.to_numeric(df['Reviews'])

# %% [markdown]
# ##### 4. How many duplicated apps are there?

# %%
#How many duplicated apps are there?
df['App'].duplicated(keep=False).sum()
# Out:
# 1979

# %% [markdown]
# ###### 5. Drop duplicated apps keeping the ones with the greatest number of reviews

# %%
#Drop duplicated apps keeping the ones with the greatest number of reviews
df_sorted = df.sort_values(by=['App', 'Reviews'])
df_sorted.loc[
    df_sorted['App'].duplicated(keep=False) & ~df_sorted.duplicated(keep=False),
    ['App', 'Reviews']
].head(5)
# Out:
#                           App   Reviews
# 5415  365Scores - Live Scores    666246
# 3083  365Scores - Live Scores    666521
# 3953              8 Ball Pool  14184910
# 1675              8 Ball Pool  14198297
# 1703              8 Ball Pool  14198602

# %% [markdown]
# ##### 6. Format the `Category` column

# %%
#Format the Category column
df['Category'] = df['Category'].str.replace('_', ' ').str.capitalize()

# %% [markdown]
# ##### 7. Clean and convert the `Installs` column to numeric type

# %%
#Clean and convert the Installs column to numeric type
df['Installs'] = df['Installs'].str.replace('+', '').str.replace(',', '')
df['Installs'] = pd.to_numeric(df['Installs'])

# %% [markdown]
# ##### 8. Clean and convert the `Size` column to numeric (representing bytes)

# %%
#Clean and convert the Size column to numeric (representing bytes)
df['Size'] = df['Size'].replace('Varies with device', "0").astype(str)

df.loc[df['Size'].str.contains('M'), 'Size'] = (pd.to_numeric(
    df.loc[df['Size'].str.contains('M'), 'Size'].str.replace('M', '')
) * (1024 * 1024)).astype(str)

df.loc[df['Size'].str.contains('k'), 'Size'] = (pd.to_numeric(
    df.loc[df['Size'].str.contains('k'), 'Size'].str.replace('k', '')
) * 1024).astype(str)

df['Size'] = df['Size'].str.replace('+', '')
df['Size'] = df['Size'].str.replace(',', '')
df['Size'] = pd.to_numeric(df['Size'])

# %% [markdown]
# ##### 9. Clean and convert the `Price` column to numeric

# %%
#Clean and convert the Price column to numeric
df.loc[df['Price'] == 'Free', 'Price'] = "0"
df['Price'] = df['Price'].str.replace('$', '').str.replace(',', '.')
df['Price'] = pd.to_numeric(df['Price'])

# %% [markdown]
# ##### 10. Paid or free?

# %%
#Paid or free?
df['Distribution'] = df['Price'].apply(lambda x: 'Paid' if x > 0 else 'Free')

# %% [markdown]
# # Analysis

# %% [markdown]
# ##### 11. What company has the most reviews?

# %%
#What company has the most reviews?
df.sort_values(by='Reviews', ascending=False)
# Out:
#                            App            Category    Rating   Reviews
# 2544                  Facebook              Social  4.100000  78158306  \
# 3943                  Facebook              Social  4.100000  78128208
# 336         WhatsApp Messenger       Communication  4.400000  69119316
# 381         WhatsApp Messenger       Communication  4.400000  69119316
# 3904        WhatsApp Messenger       Communication  4.400000  69109672
# ...                        ...                 ...       ...       ...
# 2473  Warfarin Dose Calculator             Medical  4.191757         0
# 9913       Programi podrške EU       Communication  4.191757         0
# 2471  MyWoundDoctor - Provider             Medical  4.191757         0
# 2470  Lord Fairfax EMS Council             Medical  4.191757         0
# 6962               Kick Axe Bx  Health and fitness  4.191757         0
#
#             Size    Installs  Type  Price Content Rating            Genres
# 2544         0.0  1000000000  Free    0.0           Teen            Social  \
# 3943         0.0  1000000000  Free    0.0           Teen            Social
# 336          0.0  1000000000  Free    0.0       Everyone     Communication
# 381          0.0  1000000000  Free    0.0       Everyone     Communication
# 3904         0.0  1000000000  Free    0.0       Everyone     Communication
# ...          ...         ...   ...    ...            ...               ...
# 2473   7235174.4          50  Free    0.0       Everyone           Medical
# 9913   5662310.4         100  Free    0.0       Everyone     Communication
# 2471   3670016.0           1  Free    0.0       Everyone           Medical
# 2470  31457280.0          50  Free    0.0       Everyone           Medical
# 6962   9751756.8           1  Free    0.0       Everyone  Health & Fitness
#
#           Last Updated         Current Ver         Android Ver Distribution
# 2544    August 3, 2018  Varies with device  Varies with device         Free
# 3943    August 3, 2018  Varies with device  Varies with device         Free
# 336     August 3, 2018  Varies with device  Varies with device         Free
# 381     August 3, 2018  Varies with device  Varies with device         Free
# 3904    August 3, 2018  Varies with device  Varies with device         Free
# ...                ...                 ...                 ...          ...
# 2473     July 15, 2018               3.0.0          4.1 and up         Free
# 9913  January 15, 2018               1.0.3          4.1 and up         Free
# 2471     July 27, 2018               1.2.1          5.0 and up         Free
# 2470     July 17, 2018                   1        4.0.3 and up         Free
# 6962      June 7, 2017               1.0.1          4.0 and up         Free
#
# [10829 rows x 14 columns]

# %% [markdown]
# ##### 12. Which is the category with the most most uploaded apps?

# %%
#Which is the category with the most most uploaded apps?
df['Category'].value_counts()
# Out:
# Category
# Family                 1968
# Game                   1144
# Tools                   841
# Medical                 463
# Business                460
# Productivity            424
# Personalization         390
# Communication           387
# Sports                  384
# Lifestyle               382
# Finance                 366
# Health and fitness      341
# Photography             335
# Social                  295
# News and magazines      283
# Shopping                260
# Travel and local        258
# Dating                  234
# Books and reference     230
# Video players           175
# Education               156
# Entertainment           149
# Maps and navigation     137
# Food and drink          127
# House and home           88
# Auto and vehicles        85
# Libraries and demo       84
# Weather                  82
# Events                   64
# Art and design           64
# Parenting                60
# Comics                   60
# Beauty                   53
# Name: count, dtype: int64

# %% [markdown]
# ##### 13. To which category belongs the most expensive app?

# %%
#To which category belongs the most expensive app?
df.sort_values(by='Price', ascending=False)
# Out:
#                                                    App   Category  Rating
# 4367                          I'm Rich - Trump Edition  Lifestyle     3.6  \
# 4362                                        💎 I'm rich  Lifestyle     3.8
# 5369                                         I am Rich    Finance     4.3
# 5364                    I am rich (Most expensive app)    Finance     4.1
# 5362                                     I Am Rich Pro     Family     4.4
# ...                                                ...        ...     ...
# 3651                               Weather From DMI/YR    Weather     4.3
# 3652                    wetter.com - Weather and Radar    Weather     4.2
# 3653   Storm Radar: Tornado Tracker & Hurricane Alerts    Weather     4.6
# 3654                                    Yandex.Weather    Weather     4.5
# 10840    iHoroscope - 2018 Daily Horoscope & Astrology  Lifestyle     4.5
#
#        Reviews        Size  Installs  Type   Price Content Rating
# 4367       275   7654604.8     10000  Paid  400.00       Everyone  \
# 4362       718  27262976.0     10000  Paid  399.99       Everyone
# 5369       180   3984588.8      5000  Paid  399.99       Everyone
# 5364       129   2831155.2      1000  Paid  399.99           Teen
# 5362       201   2831155.2      5000  Paid  399.99       Everyone
# ...        ...         ...       ...   ...     ...            ...
# 3651      2143         0.0    100000  Free    0.00       Everyone
# 3652    189313  39845888.0  10000000  Free    0.00       Everyone
# 3653     89868         0.0   1000000  Free    0.00       Everyone
# 3654    309617         0.0  10000000  Free    0.00       Everyone
# 10840   398307  19922944.0  10000000  Free    0.00       Everyone
#
#               Genres      Last Updated         Current Ver
# 4367       Lifestyle       May 3, 2018               1.0.1  \
# 4362       Lifestyle    March 11, 2018               1.0.0
# 5369         Finance    March 22, 2018                 1.0
# 5364         Finance  December 6, 2017                   2
# 5362   Entertainment      May 30, 2017                1.54
# ...              ...               ...                 ...
# 3651         Weather     July 31, 2018  Varies with device
# 3652         Weather    August 6, 2018  Varies with device
# 3653         Weather     June 12, 2018  Varies with device
# 3654         Weather     July 23, 2018  Varies with device
# 10840      Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver Distribution
# 4367           4.1 and up         Paid
# 4362           4.4 and up         Paid
# 5369           4.2 and up         Paid
# 5364         4.0.3 and up         Paid
# 5362           1.6 and up         Paid
# ...                   ...          ...
# 3651   Varies with device         Free
# 3652   Varies with device         Free
# 3653   Varies with device         Free
# 3654   Varies with device         Free
# 10840  Varies with device         Free
#
# [10829 rows x 14 columns]

# %% [markdown]
# ##### 14. What's the name of the most expensive game?

# %%
#What's the name of the most expensive game?
df[df['Category']=='Game'].sort_values(by='Price', ascending=False)
# Out:
#                                 App Category  Rating  Reviews        Size
# 4203        The World Ends With You     Game     4.6     4108  13631488.0  \
# 10782       Trine 2: Complete Story     Game     3.8      252  11534336.0
# 6341        Blackjack Verite Drills     Game     4.6       17   4928307.2
# 1838             Star Wars ™: DIRTY     Game     4.5    38207  15728640.0
# 6198      Backgammon NJ for Android     Game     4.4     1644  15728640.0
# ...                             ...      ...     ...      ...         ...
# 3944                 Four In A Line     Game     3.8    22191   3145728.0
# 3955             Cardi B Piano Game     Game     3.1       50   7759462.4
# 3958                MORTAL KOMBAT X     Game     4.4  3039889  18874368.0
# 3960   ► MultiCraft ― Free Miner! 👍     Game     4.3  1305050         0.0
# 10804                  Poker Pro.Fr     Game     4.2     5442  17825792.0
#
#        Installs  Type  Price Content Rating        Genres       Last Updated
# 4203      10000  Paid  17.99   Everyone 10+        Arcade  December 14, 2015  \
# 10782     10000  Paid  16.99           Teen        Action  February 27, 2015
# 6341        100  Paid  14.00           Teen        Casino       July 9, 2017
# 1838     100000  Paid   9.99           Teen  Role Playing   October 19, 2015
# 6198      10000  Paid   7.99       Everyone         Board      April 5, 2017
# ...         ...   ...    ...            ...           ...                ...
# 3944    1000000  Free   0.00       Everyone         Board        May 4, 2015
# 3955      10000  Free   0.00       Everyone         Music  November 15, 2017
# 3958   10000000  Free   0.00     Mature 17+        Action      June 27, 2018
# 3960   50000000  Free   0.00   Everyone 10+     Adventure      July 29, 2018
# 10804    100000  Free   0.00           Teen          Card       May 22, 2018
#
#       Current Ver   Android Ver Distribution
# 4203        1.0.4    4.0 and up         Paid
# 10782        2.22    5.0 and up         Paid
# 6341       1.1.10    3.0 and up         Paid
# 1838        1.0.6    4.1 and up         Paid
# 6198          4.1  2.3.3 and up         Paid
# ...           ...           ...          ...
# 3944         1.10    2.3 and up         Free
# 3955          2.0    4.0 and up         Free
# 3958       1.18.2    4.0 and up         Free
# 3960    1.1.11.11    4.1 and up         Free
# 10804       4.1.3    2.3 and up         Free
#
# [1144 rows x 14 columns]

# %% [markdown]
# ##### 15. Which is the most popular Finance App?

# %%
#Which is the most popular Finance App?
df[df['Category']=='Finance'].sort_values(by='Installs', ascending=False)
# Out:
#                App Category    Rating  Reviews        Size   Installs  Type
# 1083    Google Pay  Finance  4.200000   347838         0.0  100000000  Free  \
# 1096    Google Pay  Finance  4.200000   347838         0.0  100000000  Free
# 1163    Google Pay  Finance  4.200000   347874         0.0  100000000  Free
# 5601    Google Pay  Finance  4.200000   348132         0.0  100000000  Free
# 1156        PayPal  Finance  4.300000   659760  49283072.0   50000000  Free
# ...            ...      ...       ...      ...         ...        ...   ...
# 9104      Dz kayas  Finance  4.191757        0  14680064.0          1  Paid
# 10745      FP Boss  Finance  4.191757        1   6081740.8          1  Free
# 9101        amm dz  Finance  4.191757        0  14680064.0          1  Paid
# 9917   Eu Sou Rico  Finance  4.191757        0   1468006.4          0  Paid
# 9905   Eu sou Rico  Finance  4.191757        0   2726297.6          0  Paid
#
#         Price Content Rating   Genres     Last Updated     Current Ver
# 1083     0.00       Everyone  Finance    July 26, 2018  2.70.206190089  \
# 1096     0.00       Everyone  Finance    July 26, 2018  2.70.206190089
# 1163     0.00       Everyone  Finance    July 26, 2018  2.70.206190089
# 5601     0.00       Everyone  Finance    July 26, 2018  2.70.206190089
# 1156     0.00       Everyone  Finance    July 18, 2018          6.28.0
# ...       ...            ...      ...              ...             ...
# 9104    28.99       Everyone  Finance    July 12, 2018             1.0
# 10745    0.00       Everyone  Finance    July 27, 2018           1.0.2
# 9101     5.99       Everyone  Finance     July 8, 2018             1.0
# 9917   394.99       Everyone  Finance    July 11, 2018             1.0
# 9905    30.99       Everyone  Finance  January 9, 2018             1.0
#
#               Android Ver Distribution
# 1083   Varies with device         Free
# 1096   Varies with device         Free
# 1163   Varies with device         Free
# 5601   Varies with device         Free
# 1156           4.4 and up         Free
# ...                   ...          ...
# 9104           4.2 and up         Paid
# 10745          5.0 and up         Free
# 9101           4.2 and up         Paid
# 9917         4.0.3 and up         Paid
# 9905           4.0 and up         Paid
#
# [366 rows x 14 columns]

# %% [markdown]
# ##### 16. What *Teen* Game has the most reviews?

# %%
#What Teen Game has the most reviews?
df[(df['Category']=='Game') & (df['Content Rating']=='Teen')].sort_values(by='Reviews', ascending=False)
# Out:
#                                   App Category    Rating  Reviews
# 3912              Asphalt 8: Airborne     Game  4.500000  8389714  \
# 5417        Mobile Legends: Bang Bang     Game  4.400000  8219586
# 1988           Hungry Shark Evolution     Game  4.500000  6074627
# 1758           Hungry Shark Evolution     Game  4.500000  6074334
# 3973           Hungry Shark Evolution     Game  4.500000  6071542
# ...                               ...      ...       ...      ...
# 4431            Obbligo o Verità? PRO     Game  4.191757        4
# 6335           BJ card game blackjack     Game  4.191757        3
# 6555                           Sic Bo     Game  4.191757        1
# 7073  Animal Hunting: Sniper Shooting     Game  4.191757        0
# 6329    Basic Strategy Training BJ 21     Game  4.191757        0
#
#              Size   Installs  Type  Price Content Rating  Genres
# 3912   96468992.0  100000000  Free   0.00           Teen  Racing  \
# 5417  103809024.0  100000000  Free   0.00           Teen  Action
# 1988  104857600.0  100000000  Free   0.00           Teen  Arcade
# 1758  104857600.0  100000000  Free   0.00           Teen  Arcade
# 3973  104857600.0  100000000  Free   0.00           Teen  Arcade
# ...           ...        ...   ...    ...            ...     ...
# 4431    3040870.4        100  Paid   0.99           Teen   Board
# 6335   22020096.0        500  Free   0.00           Teen    Card
# 6555   11534336.0        100  Paid   1.99           Teen    Card
# 7073   50331648.0         50  Free   0.00           Teen  Action
# 6329   24117248.0        500  Free   0.00           Teen  Casino
#
#           Last Updated  Current Ver   Android Ver Distribution
# 3912      July 4, 2018       3.7.1a  4.0.3 and up         Free
# 5417     July 24, 2018  1.2.97.3042  4.0.3 and up         Free
# 1988     July 25, 2018        6.0.0    4.1 and up         Free
# 1758     July 25, 2018        6.0.0    4.1 and up         Free
# 3973     July 25, 2018        6.0.0    4.1 and up         Free
# ...                ...          ...           ...          ...
# 4431    April 26, 2018         1,01    3.0 and up         Paid
# 6335  December 2, 2016          1.0    2.3 and up         Free
# 6555   August 27, 2013        1.0.0    2.2 and up         Paid
# 7073      July 6, 2018          1.0    4.0 and up         Free
# 6329     March 7, 2016          1.1    2.3 and up         Free
#
# [331 rows x 14 columns]

# %% [markdown]
# ##### 17. What paid game has the most reviews?

# %%
#What paid game has the most reviews?
df[(df['Distribution'] == 'Free') & (df['Category']=='Game')].sort_values(by='Reviews', ascending=False)
# Out:
#                                 App Category    Rating   Reviews         Size
# 1879                 Clash of Clans     Game  4.600000  44893888  102760448.0  \
# 1704                 Clash of Clans     Game  4.600000  44891723  102760448.0
# 1670                 Clash of Clans     Game  4.600000  44891723  102760448.0
# 1917                 Subway Surfers     Game  4.500000  27725352   79691776.0
# 1872                 Subway Surfers     Game  4.500000  27725352   79691776.0
# ...                             ...      ...       ...       ...          ...
# 8580                   DM Adventure     Game  4.191757         0   11534336.0
# 6329  Basic Strategy Training BJ 21     Game  4.191757         0   24117248.0
# 5824                  Cyborg AX-001     Game  4.191757         0          0.0
# 8822    Simple x3DS Emulator - BETA     Game  4.191757         0          0.0
# 5855  Ay Vamos - PJ. Balvin - Piano     Game  4.191757         0   30408704.0
#
#         Installs  Type  Price Content Rating     Genres   Last Updated
# 1879   100000000  Free    0.0   Everyone 10+   Strategy  July 15, 2018  \
# 1704   100000000  Free    0.0   Everyone 10+   Strategy  July 15, 2018
# 1670   100000000  Free    0.0   Everyone 10+   Strategy  July 15, 2018
# 1917  1000000000  Free    0.0   Everyone 10+     Arcade  July 12, 2018
# 1872  1000000000  Free    0.0   Everyone 10+     Arcade  July 12, 2018
# ...          ...   ...    ...            ...        ...            ...
# 8580          10  Free    0.0       Everyone  Adventure  June 18, 2018
# 6329         500  Free    0.0           Teen     Casino  March 7, 2016
# 5824          50  Free    0.0   Everyone 10+     Action  June 25, 2018
# 8822       50000  Free    0.0       Everyone     Arcade  June 13, 2018
# 5855           5  Free    0.0       Everyone     Arcade   July 9, 2018
#
#              Current Ver         Android Ver Distribution
# 1879           10.322.16          4.1 and up         Free
# 1704           10.322.16          4.1 and up         Free
# 1670           10.322.16          4.1 and up         Free
# 1917              1.90.0          4.1 and up         Free
# 1872              1.90.0          4.1 and up         Free
# ...                  ...                 ...          ...
# 8580               1.0.4          2.3 and up         Free
# 6329                 1.1          2.3 and up         Free
# 5824  Varies with device  Varies with device         Free
# 8822  Varies with device  Varies with device         Free
# 5855                 1.0          4.1 and up         Free
#
# [1061 rows x 14 columns]

# %% [markdown]
# ##### 18. How many TB (terabytes) were transferred (overall) for the most popular Lifestyle app?

# %%
#How many TB (terabytes) were transferred (overall) for the most popular Lifestyle app?
a = df[df['Category']=='Lifestyle'].sort_values(by='Installs', ascending=False).iloc[0]
a['Installs']*a['Size']/1024**4
# Out:
# 6484.9853515625
